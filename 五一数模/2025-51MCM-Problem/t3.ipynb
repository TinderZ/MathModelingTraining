# %% [markdown]
# ## t3

# %% [markdown]
# ### 三次多项式

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 读取数据
df = pd.read_excel('待拟合函数.xlsx', sheet_name='Sheet1')

# 创建特征
df['I'] = df['x'].apply(lambda x: 1 if 13 <= x <= 17 else 0)
df['x_squared'] = df['x']**2
df['x_3'] = df['x']**3
df['I_x'] = df['I'] * df['x']
df['I_intercept'] = df['I']  # 线性修正的截距项

# 构建特征矩阵和标签
X = df[['x', 'x_squared', 'x_3', 'I_intercept', 'I_x']]
y = df['y']

# 拟合模型
model = LinearRegression()
model.fit(X, y)

# 提取系数
a0 = model.intercept_
a1, a2, a3, b0, b1 = model.coef_

# 定义分段函数
def fitted_func(x):
    base = a0 + a1*x + a2*x**2 + a3*x**3
    if 13 <= x <= 17:
        return base + b0 + b1*x
    else:
        return base

# 预测并绘图
x_values = np.linspace(8, 24, 200)
y_pred = [fitted_func(x) for x in x_values]

plt.figure(figsize=(10, 6))
plt.scatter(df['x'], df['y'], color='red', label='实际数据')
plt.plot(x_values, y_pred, label='拟合曲线', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
plt.savefig('function_fit.png')


# 输出拟合公式
print(f"全局多项式公式: {a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³")
print(f"修正项公式 (13≤x≤17): + ({b0:.4f} + {b1:.4f}x)")
print(f"完整公式:")
print("当 x <13 或 x>17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³")
print("当 13≤x≤17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³ + {b0:.4f} + {b1:.4f}x")
# Out:
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25454 (\N{CJK UNIFIED IDEOGRAPH-636E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25311 (\N{CJK UNIFIED IDEOGRAPH-62DF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 全局多项式公式: -84.4400 + 11.1950x + 0.0000x² + -0.0100x³
# 修正项公式 (13≤x≤17): + (34.0000 + -0.6500x)
# 完整公式:
# 当 x <13 或 x>17 时: y = -84.4400 + 11.1950x + 0.0000x² + -0.0100x³
# 当 13≤x≤17 时: y = -84.4400 + 11.1950x + 0.0000x² + -0.0100x³ + 34.0000 + -0.6500x

# %%
'''
Author: Zhurun Zhang
Date: 2025-05-01 22:53:15
LastEditors: Zhurun Zhang
LastEditTime: 2025-05-03 10:17:47
FilePath: \五一数模\2025-51MCM-Problem\t3.ipynb
Description: Always happy to chat! Reach out via email < b23042510@njupt.edu.cn or 2857895300@qq.com >

'''
# 计算预测值
y_pred = [fitted_func(x) for x in df['x']]  # 使用自定义函数计算预测值
df['y_pred'] = y_pred  # 将预测值添加到数据框中
# 计算各项误差指标
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(df['y'], y_pred)
mae = mean_absolute_error(df['y'], y_pred)
r2 = r2_score(df['y'], y_pred)

# 打印误差指标
print("\n误差分析报告：")
print(f"均方误差 (MSE): {mse:.4f}")
print(f"平均绝对误差 (MAE): {mae:.4f}")
print(f"R²决定系数: {r2:.8f}")

# 计算并打印每个点的绝对误差
df['绝对误差'] = np.abs(df['y'] - y_pred)
print("\n各点误差详情：")
print(df[['x', 'y', 'y_pred','绝对误差']])

# 绘制残差图
plt.figure(figsize=(10, 4))
plt.scatter(df['x'], df['y'] - y_pred, color='blue', s=50, alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.title('残差图')
plt.xlabel('x')
plt.ylabel('残差 (实际值 - 预测值)')
plt.grid(True)
plt.tight_layout()
plt.savefig('residual_plot.png')
plt.show()
# Out:
# 误差分析报告：
# 均方误差 (MSE): 0.0000
# 平均绝对误差 (MAE): 0.0000
# R²决定系数: 1.00000000
#
# 各点误差详情：
#      x       y        y_pred          绝对误差
# 0    8   0.000  2.069456e-13  2.069456e-13
# 1    9   9.025  9.025000e+00  1.492140e-13
# 2   10  17.510  1.751000e+01  9.592327e-14
# 3   11  25.395  2.539500e+01  5.684342e-14
# 4   12  32.620  3.262000e+01  0.000000e+00
# 5   13  64.675  6.467500e+01  8.526513e-14
# 6   14  69.750  6.975000e+01  5.684342e-14
# 7   15  73.985  7.398500e+01  2.842171e-14
# 8   16  77.320  7.732000e+01  0.000000e+00
# 9   17  79.695  7.969500e+01  2.842171e-14
# 10  18  58.750  5.875000e+01  2.557954e-13
# 11  19  59.675  5.967500e+01  3.126388e-13
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:39: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_16352\3753107491.py:40: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 四次多项式

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 读取数据
df = pd.read_excel('待拟合函数.xlsx', sheet_name='Sheet1')

# 创建特征
df['I'] = df['x'].apply(lambda x: 1 if 13 <= x <= 17 else 0)
df['x_squared'] = df['x']**2
df['x_3'] = df['x']**3
df['x_4'] = df['x']**4
df['I_x'] = df['I'] * df['x']
df['I_intercept'] = df['I']  # 线性修正的截距项

# 构建特征矩阵和标签
X = df[['x', 'x_squared', 'x_3', 'x_4', 'I_intercept', 'I_x']]
y = df['y']

# 拟合模型
model = LinearRegression()
model.fit(X, y)

# 提取系数
a0 = model.intercept_
a1, a2, a3, a4, b0, b1 = model.coef_

# 定义分段函数
def fitted_func(x):
    base = a0 + a1*x + a2*x**2 + a3*x**3 + a4*x**4
    if 13 <= x <= 17:
        return base + b0 + b1*x
    else:
        return base

# 预测并绘图
x_values = np.linspace(8, 24, 200)
y_pred = [fitted_func(x) for x in x_values]

plt.figure(figsize=(10, 6))
plt.scatter(df['x'], df['y'], color='red', label='实际数据')
plt.plot(x_values, y_pred, label='拟合曲线', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
plt.savefig('function_fit-together_4.png')


# 输出拟合公式
print(f"全局多项式公式: {a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³ + {a4:.4f}x⁴")
print(f"修正项公式 (13≤x≤17): + ({b0:.4f} + {b1:.4f}x)")
print(f"完整公式:")
print("当 x <13 或 x>17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³ + {a4:.4f}x⁴")
print("当 13≤x≤17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {a3:.4f}x³ + {a4:.4f}x⁴ +{b0:.4f} + {b1:.4f}x")
# Out:
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25454 (\N{CJK UNIFIED IDEOGRAPH-636E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25311 (\N{CJK UNIFIED IDEOGRAPH-62DF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 全局多项式公式: -87.1029 + 11.9898x + -0.0837x² + -0.0063x³ + -0.0001x⁴
# 修正项公式 (13≤x≤17): + (33.9842 + -0.6452x)
# 完整公式:
# 当 x <13 或 x>17 时: y = -87.1029 + 11.9898x + -0.0837x² + -0.0063x³ + -0.0001x⁴
# 当 13≤x≤17 时: y = -87.1029 + 11.9898x + -0.0837x² + -0.0063x³ + -0.0001x⁴ +33.9842 + -0.6452x

# %%
# 新增误差计算代码 ----------------------------------------------------
# 计算预测值
y_pred = [fitted_func(x) for x in df['x']]  # 使用自定义函数计算预测值

# 计算各项误差指标
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(df['y'], y_pred)
mae = mean_absolute_error(df['y'], y_pred)
r2 = r2_score(df['y'], y_pred)

# 打印误差指标
print("\n误差分析报告：")
print(f"均方误差 (MSE): {mse:.4f}")
print(f"平均绝对误差 (MAE): {mae:.4f}")
print(f"R²决定系数: {r2:.4f}")

# 计算并打印每个点的绝对误差
df['绝对误差'] = np.abs(df['y'] - y_pred)
print("\n各点误差详情：")
print(df[['x', 'y', '绝对误差']])

# 绘制残差图
plt.figure(figsize=(10, 4))
plt.scatter(df['x'], df['y'] - y_pred, color='blue', s=50, alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.title('残差图')
plt.xlabel('x')
plt.ylabel('残差 (实际值 - 预测值)')
plt.grid(True)
plt.tight_layout()
plt.savefig('residual_plot.png')
plt.show()
# Out:
# 误差分析报告：
# 均方误差 (MSE): 0.0053
# 平均绝对误差 (MAE): 0.0402
# R²决定系数: 1.0000
#
# 各点误差详情：
#      x       y      绝对误差
# 0    8   0.000  0.015357
# 1    9   9.025  0.012548
# 2   10  17.510  0.015860
# 3   11  25.395  0.003675
# 4   12  32.620  0.016263
# 5   13  64.675  0.008936
# 6   14  69.750  0.003906
# 7   15  73.985  0.009401
# 8   16  77.320  0.005223
# 9   17  79.695  0.009594
# 10  18  58.750  0.035792
# 11  19  59.675  0.006998
# 12  20  59.460  0.027214
# 13  21  58.045  0.062394
# 14  22  55.370  0.092735
# 15  23  51.735  0.248922
# 16  24  46.000  0.108906
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 二次多项式

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 读取数据
df = pd.read_excel('待拟合函数.xlsx', sheet_name='Sheet1')

# 创建特征
df['I'] = df['x'].apply(lambda x: 1 if 13 <= x <= 17 else 0)
df['x_squared'] = df['x']**2
df['I_x'] = df['I'] * df['x']
df['I_intercept'] = df['I']  # 线性修正的截距项

# 构建特征矩阵和标签
X = df[['x', 'x_squared', 'I_intercept', 'I_x']]
y = df['y']

# 拟合模型
model = LinearRegression()
model.fit(X, y)

# 提取系数
a0 = model.intercept_
a1, a2, b0, b1 = model.coef_

# 定义分段函数
def fitted_func(x):
    base = a0 + a1*x + a2*x**2
    if 13 <= x <= 17:
        return base + b0 + b1*x
    else:
        return base

# 预测并绘图
x_values = np.linspace(9, 24, 200)
y_pred = [fitted_func(x) for x in x_values]

plt.figure(figsize=(10, 6))
plt.scatter(df['x'], df['y'], color='red', label='实际数据')
plt.plot(x_values, y_pred, label='拟合曲线', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# 输出拟合公式
print(f"全局多项式公式: {a0:.4f} + {a1:.4f}x + {a2:.4f}x²")
print(f"修正项公式 (13≤x≤17): + ({b0:.4f} + {b1:.4f}x)")
print(f"完整公式:")
print("当 x <13 或 x>17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x²")
print("当 13≤x≤17 时: y =", f"{a0:.4f} + {a1:.4f}x + {a2:.4f}x² + {b0:.4f} + {b1:.4f}x")
# Out:
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25454 (\N{CJK UNIFIED IDEOGRAPH-636E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25311 (\N{CJK UNIFIED IDEOGRAPH-62DF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 全局多项式公式: -125.6018 + 19.3879x + -0.5080x²
# 修正项公式 (13≤x≤17): + (28.9801 + -0.3859x)
# 完整公式:
# 当 x <13 或 x>17 时: y = -125.6018 + 19.3879x + -0.5080x²
# 当 13≤x≤17 时: y = -125.6018 + 19.3879x + -0.5080x² + 28.9801 + -0.3859x

# %%
# 新增误差计算代码 ----------------------------------------------------
# 计算预测值
y_pred = [fitted_func(x) for x in df['x']]  # 使用自定义函数计算预测值

# 计算各项误差指标
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(df['y'], y_pred)
mae = mean_absolute_error(df['y'], y_pred)
r2 = r2_score(df['y'], y_pred)

# 打印误差指标
print("\n误差分析报告：")
print(f"均方误差 (MSE): {mse:.4f}")
print(f"平均绝对误差 (MAE): {mae:.4f}")
print(f"R²决定系数: {r2:.4f}")

# 计算并打印每个点的绝对误差
df['绝对误差'] = np.abs(df['y'] - y_pred)
print("\n各点误差详情：")
print(df[['x', 'y', '绝对误差']])

# 绘制残差图
plt.figure(figsize=(10, 4))
plt.scatter(df['x'], df['y'] - y_pred, color='blue', s=50, alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.title('残差图')
plt.xlabel('x')
plt.ylabel('残差 (实际值 - 预测值)')
plt.grid(True)
plt.tight_layout()
plt.savefig('residual_plot.png')
plt.show()
# Out:
# 误差分析报告：
# 均方误差 (MSE): 0.3706
# 平均绝对误差 (MAE): 0.4268
# R²决定系数: 0.9991
#
# 各点误差详情：
#      x       y      绝对误差
# 0    9   9.025  1.286363
# 1   10  17.510  0.036108
# 2   11  25.395  0.798079
# 3   12  32.620  1.276197
# 4   13  64.675  0.128069
# 5   14  69.750  0.082034
# 6   15  73.985  0.116069
# 7   16  77.320  0.034034
# 8   17  79.695  0.104069
# 9   18  58.750  0.027461
# 10  19  59.675  0.306903
# 11  20  59.460  0.517334
# 12  21  58.045  0.543835
# 13  22  55.370  0.326404
# 14  23  51.735  0.165042
# 15  24  46.000  1.080252
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:31: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# C:\Users\Zhurun Zhang\AppData\Local\Temp\ipykernel_39232\3182821867.py:32: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.savefig('residual_plot.png')
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27531 (\N{CJK UNIFIED IDEOGRAPH-6B8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24046 (\N{CJK UNIFIED IDEOGRAPH-5DEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### t ->  t+1

# %%
import sympy as sp

t = sp.symbols('t')
f_t_minus_1 = -84.5071 + 11.2212*t - 0.0028*t**2 - 0.0099*t**3
f_t = f_t_minus_1.subs(t, t + 1)
f_t_expanded = sp.expand(f_t)
print("f(t) =", f_t_expanded)
# Out:
# f(t) = -0.0099*t**3 - 0.0325*t**2 + 11.1859*t - 73.2986

# %%
import sympy as sp

t = sp.symbols('t')
f_t_minus_1 = 84.8 - 0.85*t 
f_t = f_t_minus_1.subs(t, t + 1)
f_t_expanded = sp.expand(f_t)
print("f(t) =", f_t_expanded)
# Out:
# f(t) = 83.95 - 0.85*t

# %% [markdown]
# #### 计算某时刻 t=15,45 车流量数值

# %%
import sympy as sp

# 定义符号变量 t
t = sp.symbols('t')

# 定义 f(t)
f_t = -0.0099*t**3 - 0.0325*t**2 + 11.1859*t - 73.2986

# 代入 t 值（例如 t = 10）
t_value = 14
result = f_t.subs(t, t_value).evalf()  # .evalf() 转为浮点数

print(f"f({t_value}) =", result)
# Out:
# f(14) = 49.7684000000000
